# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/Fundamentos-tecnicos-y-aplicaciones-ML/blob/main/Semana%201/1_4_Ecuaciones_lineales_y_sistemas_de_ecuaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Graficar ecuación lineal en dos dimensiones

# %%
x = np.array([1, -1])
y = 2*x + 4
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Añadir información al gráfico

# %%
plt.plot(x, y, label ='2x+4')
plt.title ('Mi primer función en Python')
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.grid(alpha=.8, linestyle='--')

plt.legend()
plt.show()

# %% [markdown]
# ## Grafica de dos ecuaciones

# %%
plt.plot(x, y, label ='2x+4')
plt.plot(x, -3*x+2, label ='-3x+2')

plt.title ('Mi primer función en Python')
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.grid(alpha=.8, linestyle='--')

plt.legend()
plt.show()

# %% [markdown]
# # Grafica de ecuación lineal en tres dimensiones
#
# si una linea es la representación una ecuación lineal en dos dimensiónes ¿cuál es la representación lineal de una ecuación lineal en tres dimensiones?
#
# 2x + 3y - Z = 1

# %%
# La estrategia es graficar z en función de x y y.
# Para ello creamos distintos puntos con cordenadas en x y y 
x, y = np.linspace(0, 2, 10), np.linspace(0, 2, 10)
X, Y = np.meshgrid( x, y)

plt.plot(X, Y,'bo')
plt.show()

# %%
Z = 2*X + 3*Y -1

fig = plt.figure(figsize = (8, 8))
ax= fig.gca(projection ='3d')  # equivalente a ax = fig.add_subplot(111, projection....

ax.plot_surface(X, Y, Z, alpha = .8)

ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')

plt.show()

# %% [markdown]
# # Solución a un sistema de ecuaciones con dos variables

# %% [markdown]
# Supongamos que queremor resolver y luego graficar el siguiente sistema de ecuaciones
#
# `-3x + y = 4`
#
# ` 2x + y = 1`

# %%
#Matriz de coeficientes
M = np.array([[-3, 1], [2, 1]]) 

# vector con las cantidades al lado derecho de las ecuaciones
b =  np.array([4, 1])

solucion = np.linalg.solve(M, b)
solucion
# Out:
# array([-0.6,  2.2])

# %% [markdown]
# Creamos una función

# %%
def solucion_ecuaciones_2D(A1, B1, C1, A2, B2, C2):
    '''soluciona un sistema de dos ecuaciones con dos incónitas. 
    Cada ecuación debe estar ordenada de la siguiente forma:
    Ax + By = C'''
    M = np.array([[A1, B1], [A2, B2]])
    b = np.array([C1, C2])
    solucion = np.linalg.solve(M, b)
    return solucion

# %%
solucion_ecuaciones_2D(-3,1,4,2,1,1)
# Out:
# array([-0.6,  2.2])

# %% [markdown]
# ## Solución gráfica

# %%
x = np.linspace(-4, 4, 2) 

#despejamos la y
y1 =  3*x + 4
y2 = -2*x + 1 

fig = plt.figure(figsize = (6, 4))

#crear grafico de linea que representa las ecuaciones
plt.plot(x, y1, label ='y = 3x + 4')      # ecuación 1
plt.plot(x, y2, label = 'y = -2x+1')  # ecuación 2 
plt.plot(-0.6, 2.2, marker='o', label= (solucion[0], solucion[1]))

#título
plt.title ('Solucion gráfica de un sistema ecuaciones 2 dimensiones')

#etiquetas de los ejes
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

#cuadrícula
plt.grid(alpha=.8, linestyle='--')

#limites de los ejes
plt.xlim(-3,3)
plt.ylim(-5,5)


#agregar etiqueta de valores
plt.legend( )

#mostrar la gráfica
plt.show()

# %%
def solucion_grafica_2D(A1, B1, C1, A2, B2, C2):
    '''Solución gráfica a un sistema de dos ecuaciones
    Cada ecuación debe estar ordenada de la siguiente forma:
    Ax + By = C'''

    solucion = solucion_ecuaciones_2D(A1, B1, C1, A2, B2, C2)
    lim = 2 * solucion[np.argmax(solucion)]
    x = np.linspace(-lim, lim, 5) 

    #despejamos la y
    y1 = (C1 - A1*x)/B1
    y2 = (C2 - A2*x)/B2

    fig = plt.figure(figsize = (6, 4))

    #crear grafico de linea que representa las ecuaciones
    plt.plot(x, y1, label ='ecuacion 1')     
    plt.plot(x, y2, label = 'ecuacion 2')  
    plt.plot(solucion[0], solucion[1], marker='o', label= 'solución')

    #título
    plt.title ('Solucion gráfica de un sistema ecuaciones 2 dimensiones')

    #etiquetas de los ejes
    plt.xlabel('Eje X')
    plt.ylabel('Eje Y')

    #cuadrícula
    plt.grid(alpha=.8, linestyle='--')

    #agregar etiqueta de valores
    plt.legend( )

    #mostrar la gráfica
    plt.show()

    return solucion[0], solucion[1]

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 1. ¿Cuál es el área de un rectángulo si su perimentro mide 16 y la base mide el triple que la altura?
# (Incluye la solución gráfica)

# %% [markdown]
# 2. En una industria textil trabajan 60 personas. 11 personas trabajan en tareas administrativas. Sabemos además que 16% de los hombres y 20% de las mujeres tienen trabajos administrativos.
# ¿cuántos hombres y cuántas mujeres hay?
# (Incluye la solucion gráfica)

# %% [markdown]
# #  Solucion a un sistemas de ecuaciones con tres variables

# %% [markdown]
# Supongamos que queremos resolver y luego graficar el siguientes sistemas de ecuaciones:
#
# ```
# 4x -2y + z =11
# -2x +4y -2z = -16
# x -2y + 4z = 17
# ```

# %%
#Matriz de coeficientes
M = np.array([[4., -2., 1.], [-2., 4., -2.], [1., -2., 4.]]) 

# vector con las cantidades al lado derecho de las ecuaciones
b =  np.array([11, -16, 17])

solucion = np.linalg.solve(M, b)
solucion
# Out:
# array([ 1., -2.,  3.])

# %% [markdown]
# ## Solución gráfica

# %%
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(111, projection='3d')

#vamos a graficar a z en función de x y y, para ello creamos primero los planos x, y

x, y = np.linspace(-8, 8,50), np.linspace(-8,8,50)
X, Y = np.meshgrid(x, y)

# despejamos en las tres ecuaciones a Z
Z1 = 11 - 4*X + 2*Y
Z2 = (16 - 2*X + 4*Y) / 2
Z3 = (17 - X + 2*Y) / 4

#superficie de la ecuación 1
ax.plot_surface(X, Y, Z1, alpha=.6, color='cyan',) 

 #superficie de la ecuación 2
ax.plot_surface(X, Y, Z2, alpha=.6, color='yellow')

#linea de intetersección entre la superficies de las primeras dos ecuaciones
ax.plot((1, 1),(-8, 8), (-9,23), lw=3,  c='blue')

#superficie de la ecuación 3
ax.plot_surface(X, Y, Z3, alpha=.3, color='red')

#solución
ax.plot(xs=[1],ys=[-2], zs=[3], c='black',  marker='o')  

ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')

plt.show()

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 3. Encuentra el valor de las tres variables `x`, `y`, `z`, utilizando la función `solve` del modulo de algebra lineal de numpy, a partir del siguiente sistema de ecuaciones:
#
# ```
# 2x + 3y - z = 7
# x + 4y + 2z = 2
# x + y + z = 4
# ```

# %% [markdown]
# 4. Encuentra el valor de las tres variables `x`, `y`, `z`, utilizando la función `solve` del modulo de algebra lineal de numpy, a partir del siguiente sistema de ecuaciones:
#
# ```
# x + y - 3z = -10
# x + y + 2z = 3
# 2x + y - z = 4
# ```

# %% [markdown]
# #  Solucion a un sistemas de ecuaciones en más de 3 dimensiones

# %% [markdown]
# Considere el siguiene sistema de ecuaciones:
#
# ```
# a + b + c + d = 4
# 2a + 3b -c + d = 10
# a - b + c - d = -2
# a + 2b + 3c - d = -1
# ```
# Vamos a encontrar el valor de a, b, c y d usando la función `solve` de numpy

# %%
coeficientes = np.array([
                         [1,  1,  1,  1],
                         [2,  3, -1,  1],
                         [1, -1,  1, -1],
                         [1,  2,  3, -1]
                         ])

resultados = np.array([4, 10, -2, -1])

a, b, c, d = np.linalg.solve(coeficientes, resultados)

print('a = {:.1f} \nb = {:.1f} \nc = {:.1f} \nd = {:.1f}'.format(a, b, c, d))
# Out:
# a = 2.0
# b = 1.0
# c = -1.0
# d = 2.0
